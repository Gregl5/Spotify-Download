# %% [markdown]
# <a href="https://colab.research.google.com/github/Gregl5/Spotify-Download/blob/main/SD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install nodejs
# !git clone https://github.com/SwapnilSoni1999/spotify-dl

# %%
cd spotify-dl

# %%
# !npm install

# %%
# !npm link

# %%
# !spotifydl <url>

# %%
ls

# %%
from google.colab import files
files.download('song name')
